# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import sys
sys.path.insert(1, 'C:/Users/pnknv/Documents/GitHub/yadisk_loader')
from main_utils import *

# %%
ssh_host, ssh_port, ssh_username, ssh_password, \
database_username, database_password, database_name, \
localhost, localhost_port, table_name, ya_token, ya_api, ya_link = get_config()

# %%
sql_server, sql_engine = get_sql_engine()

# %%
cian = pd.read_csv('циан 06-05-23 (без дублей).csv')

# %%
cian
# Out:
#                                                   Ссылка  \
# 0       https://novosibirsk.cian.ru/sale/flat/283051397/
# 1       https://novosibirsk.cian.ru/sale/flat/283030178/
# 2             https://kazan.cian.ru/sale/flat/283109034/
# 3             https://kazan.cian.ru/sale/flat/283109032/
# 4       https://chelyabinsk.cian.ru/sale/flat/286732915/
# ...                                                  ...
# 126107        https://kazan.cian.ru/sale/flat/286990349/
# 126108        https://kazan.cian.ru/sale/flat/286990262/
# 126109        https://kazan.cian.ru/sale/flat/286990307/
# 126110        https://kazan.cian.ru/sale/flat/278050740/
# 126111        https://kazan.cian.ru/sale/flat/285910915/
#
#                                 Заголовок       Комнат   Площадь        Этаж  \
# 0        4-комн. кв., 85,4 м², 13/17 этаж  4-комн. кв.   85,4 м²  13/17 этаж
# 1           3-комн. кв., 82 м², 5/19 этаж  3-комн. кв.     82 м²   5/19 этаж
# 2       3-комн. кв., 57,99 м², 18/20 этаж  3-комн. кв.  57,99 м²  18/20 этаж
# 3        2-комн. кв., 48,7 м², 18/20 этаж  2-комн. кв.   48,7 м²  18/20 этаж
# 4              Студия, 24,1 м², 9/11 этаж       Студия   24,1 м²   9/11 этаж
# ...                                   ...          ...       ...         ...
# 126107    2-комн. кв., 60,39 м², 3/5 этаж  2-комн. кв.  60,39 м²    3/5 этаж
# 126108    1-комн. кв., 47,65 м², 2/5 этаж  1-комн. кв.  47,65 м²    2/5 этаж
# 126109    1-комн. кв., 44,49 м², 5/5 этаж  1-комн. кв.  44,49 м²    5/5 этаж
# 126110    2-комн. кв., 70,19 м², 4/9 этаж  2-комн. кв.  70,19 м²    4/9 этаж
# 126111   3-комн. кв., 53,65 м², 5/15 этаж  3-комн. кв.  53,65 м²   5/15 этаж
#
#             Цена  Цена за м2           Название жк  \
# 0        9500000      111241  ЖК «Ельцовский парк»
# 1        9750000      118902                   NaN
# 2       15500000      267287      ЖК «Savin House»
# 3       14000000      287474      ЖК «Savin House»
# 4        2050000       85062           ЖК «Радуга»
# ...          ...         ...                   ...
# 126107  16305300      270000    ЖК «Дом на Исхаки»
# 126108  13342000      280000    ЖК «Дом на Исхаки»
# 126109  13124550      295000    ЖК «Дом на Исхаки»
# 126110  14810090      211000           ЖК «Максат»
# 126111  12715119      237001           ЖК «Яналиф»
#
#                                                     Адрес  \
# 0       Новосибирская область;Новосибирск;р-н Калининс...
# 1       Новосибирская область;Новосибирск;р-н Дзержинс...
# 2       Республика Татарстан;Казань;р-н Ново-Савиновск...
# 3       Республика Татарстан;Казань;р-н Ново-Савиновск...
# 4       Челябинская область;Челябинск;р-н Курчатовский...
# ...                                                   ...
# 126107  Республика Татарстан;Казань;р-н Вахитовский;мк...
# 126108  Республика Татарстан;Казань;р-н Вахитовский;мк...
# 126109  Республика Татарстан;Казань;р-н Вахитовский;мк...
# 126110  Республика Татарстан;Казань;р-н Вахитовский;мк...
# 126111  Республика Татарстан;Казань;р-н Вахитовский;м....
#
#                         Дата публикации            Тип продавца      Продавец
# 0          неделю назад (25 апр, 17:36)  Агентство недвижимости         Ключи
# 1                  вчера (вчера, 10:55)  Агентство недвижимости   ID 71291343
# 2                  вчера (4 май, 01:10)  Агентство недвижимости  ЭТАЖИ КАЗАНЬ
# 3                  вчера (4 май, 01:10)  Агентство недвижимости  ЭТАЖИ КАЗАНЬ
# 4          неделю назад (27 апр, 10:50)  Агентство недвижимости       ЧелСити
# ...                                 ...                     ...           ...
# 126107   5 часов назад (сегодня, 16:55)              Застройщик   Ак Барс Дом
# 126108             вчера (вчера, 16:43)              Застройщик   Ак Барс Дом
# 126109             вчера (вчера, 16:44)              Застройщик   Ак Барс Дом
# 126110  18 часов назад (сегодня, 04:25)              Застройщик     NovaStroy
# 126111  12 часов назад (сегодня, 10:07)              Застройщик        СМУ-88
#
# [126112 rows x 12 columns]

# %%
parse_avito_to_realty_prices.ipynb

# %%
cian['ad_id'] = cian['Ссылка'].apply(lambda x: x.split('/')[-2])

# %%
cian['ad_id'] = cian['ad_id'].astype('int64')

# %%
def get_exist_ad_id(engine, source):
    source_id = 2 if source == 'cian' else 3
    ad_id_query = f'SELECT ad_id FROM realty where source_id = {source_id}'
    try:
        con_obj = engine.connect()
        ad_id_db = pd.read_sql(text(ad_id_query), con=con_obj)
        con_obj.close()
        exc_code = None
    except Exception as exc:
        logging.error(traceback.format_exc())
        ad_id_db = None
        exc_code = exc.code
    return ad_id_db, exc_code

# %%
ads_prod, exc_code = get_exist_ad_id(sql_engine, 'cian')

# %%
cian[~cian.ad_id.isin(ads_prod.ad_id.to_list())]
# Out:
#                                                   Ссылка  \
# 20      https://chelyabinsk.cian.ru/sale/flat/278462664/
# 22      https://chelyabinsk.cian.ru/sale/flat/285377533/
# 101       https://krasnodar.cian.ru/sale/flat/286826988/
# 103       https://krasnodar.cian.ru/sale/flat/286501126/
# 104       https://krasnodar.cian.ru/sale/flat/286496400/
# ...                                                  ...
# 125952    https://krasnodar.cian.ru/sale/flat/287025222/
# 125953    https://krasnodar.cian.ru/sale/flat/286989303/
# 125954    https://krasnodar.cian.ru/sale/flat/286988645/
# 125955    https://krasnodar.cian.ru/sale/flat/286964767/
# 125956    https://krasnodar.cian.ru/sale/flat/286878710/
#
#                                Заголовок       Комнат   Площадь        Этаж  \
# 20         1-комн. кв., 39 м², 3/10 этаж  1-комн. кв.     39 м²   3/10 этаж
# 22      3-комн. кв., 71,57 м², 2/10 этаж  3-комн. кв.  71,57 м²   2/10 этаж
# 101         Студия, 23,18 м², 12/16 этаж       Студия  23,18 м²  12/16 этаж
# 103           Студия, 19,7 м², 2/16 этаж       Студия   19,7 м²   2/16 этаж
# 104           Студия, 19,7 м², 2/16 этаж       Студия   19,7 м²   2/16 этаж
# ...                                  ...          ...       ...         ...
# 125952      2-комн. кв., 60 м², 1/7 этаж  2-комн. кв.     60 м²    1/7 этаж
# 125953    1-комн. кв., 52 м², 16/18 этаж  1-комн. кв.     52 м²  16/18 этаж
# 125954    1-комн. кв., 47 м², 15/18 этаж  1-комн. кв.     47 м²  15/18 этаж
# 125955  1-комн. кв., 39,6 м², 16/22 этаж  1-комн. кв.   39,6 м²  16/22 этаж
# 125956  1-комн. кв., 39,4 м², 14/17 этаж  1-комн. кв.   39,4 м²  14/17 этаж
#
#            Цена  Цена за м2             Название жк  \
# 20      2500000       64103  ЖК «по ул. Завалишина»
# 22      5168040       72210     ЖК «Краснопольский»
# 101     3007141      129730      ЖК «Зелёный театр»
# 103     3152000      160000         ЖК «Dogma park»
# 104     3152000      160000         ЖК «Dogma park»
# ...         ...         ...                     ...
# 125952  6200000      103333                     NaN
# 125953  6250000      120192                     NaN
# 125954  6199999      131915           ЖК «Три кита»
# 125955  6200000      156566          ЖК «Аквамарин»
# 125956  6200000      157360              ЖК «Цветы»
#
#                                                     Адрес  \
# 20      Челябинская область;Челябинск;р-н Тракторозаво...
# 22      Челябинская область;Челябинск;р-н Курчатовский...
# 101     Краснодарский край;Краснодар;Прикубанский;Зеле...
# 103     Краснодарский край;Краснодар;Прикубанский;улиц...
# 104     Краснодарский край;Краснодар;Прикубанский;улиц...
# ...                                                   ...
# 125952  Краснодарский край;Краснодар;Карасунский;мкр. ...
# 125953  Краснодарский край;Краснодар;Карасунский;мкр. ...
# 125954  Краснодарский край;Краснодар;Прикубанский;мкр....
# 125955  Краснодарский край;Краснодар;Карасунский;мкр. ...
# 125956  Краснодарский край;Краснодар;Прикубанский;Круг...
#
#                        Дата публикации               Тип продавца  \
# 20                вчера (4 май, 01:10)     Агентство недвижимости
# 22                вчера (вчера, 04:35)                 Застройщик
# 101               вчера (вчера, 16:41)                 Застройщик
# 103     2 недели назад (20 апр, 21:01)  Представитель застройщика
# 104       три дня назад (2 май, 19:35)  Представитель застройщика
# ...                                ...                        ...
# 125952            вчера (вчера, 21:56)     Агентство недвижимости
# 125953   2 часа назад (сегодня, 20:07)     Агентство недвижимости
# 125954    три дня назад (3 май, 16:25)                Собственник
# 125955            вчера (вчера, 04:27)     Агентство недвижимости
# 125956            вчера (вчера, 04:27)     Агентство недвижимости
#
#                         Продавец      ad_id
# 20                   ID 70810011  278462664
# 22                   White Group  285377533
# 101                      Европея  286826988
# 103     Объединение застройщиков  286501126
# 104           Магазин новостроек  286496400
# ...                          ...        ...
# 125952            Девелопмент-Юг  287025222
# 125953             Красная Линия  286989303
# 125954              ID 102732531  286988645
# 125955              ЭТАЖИ-КУБАНЬ  286964767
# 125956              ЭТАЖИ-КУБАНЬ  286878710
#
# [6841 rows x 13 columns]

# %% [markdown]
# # different parses

# %%
cian[cian['Адрес'].apply(lambda x: 'Армавир' in x)]
# Out:
#                                                 Ссылка  \
# 2004    https://krasnodar.cian.ru/sale/flat/276857537/
# 2005    https://krasnodar.cian.ru/sale/flat/276060820/
# 2006    https://krasnodar.cian.ru/sale/flat/276060934/
# 2007    https://krasnodar.cian.ru/sale/flat/276857398/
# 2008    https://krasnodar.cian.ru/sale/flat/276060937/
# ...                                                ...
# 121242  https://krasnodar.cian.ru/sale/flat/285942928/
# 121246  18 часов назад (сегодня, 01:55)  Агентство недвижимости   100 Квартир
#
#             ad_id
# 2004    276857537
# 2005    276060820
# 2006    276060934
# 2007    276857398
# 2008    276060937
# ...           ...
# 121242  285942928
# 121243  285942963
# 121244  285977412
# 121245  286000701
# 121246  286073267
#
# [167 rows x 13 columns]

# %%
cian[cian.duplicated(subset=['Ссылка'])]
# Out:
# Empty DataFrame
# Columns: [Ссылка, Заголовок, Комнат, Площадь, Этаж, Цена, Цена за м2, Название жк, Адрес, Дата публикации, Тип продавца, Продавец, ad_id]
# Index: []

# %% [markdown]
# # money

# %%
files = os.listdir('saved_shit/')

# %%
files_avito = [i for i in files if 'циан' not in i]
files_cian = [i for i in files if 'циан' in i]

# %%
test_cian = pd.read_csv('saved_shit/' + files_cian[0], delimiter=',')

# %%
test_cian['ad_id'] = test_cian['Ссылка'].apply(lambda x: x.split('/')[-2])
test_cian['ad_id'] = test_cian['ad_id'].astype('int64')

# %%
test_cian
# Out:
#                                                 Ссылка  \
# 0       https://krasnodar.cian.ru/sale/flat/286046952/
# 1       https://krasnodar.cian.ru/sale/flat/286032732/
# 2       https://krasnodar.cian.ru/sale/flat/286032730/
# 3       https://krasnodar.cian.ru/sale/flat/286029930/
# 4       https://krasnodar.cian.ru/sale/flat/286020566/
# ...                                                ...
# 117291      https://sochi.cian.ru/sale/flat/277480315/
# 117292      https://sochi.cian.ru/sale/flat/277459856/
# 117293      https://sochi.cian.ru/sale/flat/277438444/
# 117294      https://sochi.cian.ru/sale/flat/277347516/
# 117295      https://sochi.cian.ru/sale/flat/277334666/
#
#                                   Заголовок              Комнат  Площадь  \
# 0             2-комн. кв., 70 м², 5/12 этаж         2-комн. кв.    70 м²
# 1           2-комн. кв., 51,5 м², 2/10 этаж         2-комн. кв.  51,5 м²
# 2             1-комн. кв., 40 м², 7/22 этаж         1-комн. кв.    40 м²
# 3          1-комн. кв., 47,8 м², 14/20 этаж         1-комн. кв.  47,8 м²
# 4              3-комн. кв., 66 м², 7/9 этаж         3-комн. кв.    66 м²
# ...                                     ...                 ...      ...
# 117291        3-комн. кв., 60 м², 2/11 этаж         3-комн. кв.    60 м²
# 117292      3-комн. кв., 101 м², 11/17 этаж         3-комн. кв.   101 м²
# 117293  Апартаменты-студия, 25 м², 4/5 этаж  Апартаменты-студия    25 м²
# 117294              Студия, 12 м², 4/4 этаж              Студия    12 м²
# 117295        3-комн. кв., 93 м², 6/20 этаж         3-комн. кв.    93 м²
#
#               Этаж      Цена  Цена за м2         Название жк  \
# 0        5/12 этаж   5700000       81429          ЖК «Парус»
# 1        2/10 этаж   5700000      110680                 NaN
# 2        7/22 этаж   5700000      142500                 NaN
# 3       14/20 этаж   5700000      119247          ЖК «Грани»
# 4         7/9 этаж   5700000       86364  ЖК «Sport Village»
# ...            ...       ...         ...                 ...
# 117291   2/11 этаж  13000000      216667                 NaN
# 117292  11/17 этаж  12300000      121782                 NaN
# 117293    4/5 этаж  12500000      500000                 NaN
# 117294    4/4 этаж  13000000     1083333                 NaN
# 117295   6/20 этаж  12900000      138710                 NaN
#
#                                                     Адрес  \
# 0       Краснодарский край;Краснодар;Прикубанский;мкр....
# 1       Краснодарский край;Краснодар;Прикубанский;мкр....
# 2       Краснодарский край;Краснодар;Прикубанский;улиц...
# 3       Краснодарский край;Краснодар;Прикубанский;улиц...
# 4       Краснодарский край;Краснодар;Прикубанский;мкр....
# ...                                                   ...
# 117291  Краснодарский край;Сочи;р-н Центральный;мкр. Д...
# 117292  Краснодарский край;Сочи;р-н Центральный;мкр. Ц...
# 117293  Краснодарский край;Сочи;р-н Центральный;мкр. Ц...
# 117294  Краснодарский край;Сочи;р-н Центральный;мкр. Н...
# 117295  Краснодарский край;Сочи;р-н Центральный;мкр. М...
#
#                          Дата публикации            Тип продавца  \
# 0                   вчера (вчера, 12:55)  Агентство недвижимости
# 1        пять дней назад (25 апр, 18:22)  Агентство недвижимости
# 2        пять дней назад (25 апр, 18:22)  Агентство недвижимости
# 3         2 недели назад (11 апр, 13:58)                 Риелтор
# 4           неделю назад (20 апр, 13:23)  Агентство недвижимости
# ...                                  ...                     ...
# 117291  четыре дня назад (27 апр, 09:18)             Собственник
# 117292    2 недели назад (13 апр, 13:54)  Агентство недвижимости
# 117293    2 недели назад (17 апр, 17:58)                 Риелтор
# 117294     полгода назад (19 сен, 23:58)             Собственник
# 117295    2 недели назад (11 апр, 19:04)  Агентство недвижимости
#
#                      Продавец      ad_id
# 0            ЧФК-Недвижимость  286046952
# 1                ЭТАЖИ-КУБАНЬ  286032732
# 2                ЭТАЖИ-КУБАНЬ  286032730
# 3                 ID 55338816  286029930
# 4              Девелопмент-Юг  286020566
# ...                       ...        ...
# 117291            ID 94977241  277480315
# 117292  Черноморский проспект  277459856
# 117293         Виктор Захаров  277438444
# 117294            ID 93157894  277347516
# 117295            ID 53767050  277334666
#
# [117296 rows x 13 columns]

# %%
test_avito = pd.read_csv('saved_shit/' + files_avito[0], delimiter=';')

# %%
test_avito['ad_id'] = test_avito['Ссылка'].apply(lambda x: x.split('_')[-1])
test_avito['ad_id'] = test_avito['ad_id'].astype('int64')

# %%
test_avito
# Out:
#                                                    Ссылка  \
# 0       https://www.avito.ru/tomsk/kvartiry/apartament...
# 1       https://www.avito.ru/tomsk/kvartiry/1-k._kvart...
# 2       https://www.avito.ru/tomsk/kvartiry/2-k._kvart...
# 3       https://www.avito.ru/tomsk/kvartiry/2-k._kvart...
# 4       https://www.avito.ru/tomsk/kvartiry/2-k._kvart...
# ...                                                   ...
# 200832  https://www.avito.ru/krasnodar/kvartiry/2-k._k...
# 200833  https://www.avito.ru/krasnodar/kvartiry/2-k._k...
# 200834  https://www.avito.ru/krasnodar/kvartiry/2-k._k...
# 200835  https://www.avito.ru/krasnodar/kvartiry/2-k._k...
# 200836  https://www.avito.ru/krasnodar/kvartiry/2-k._k...
#
#                                  Заголовок              Комнат  Площадь  \
# 0       Апартаменты-студия, 29 м², 5/5 эт.  Апартаменты-студия    29 м²
# 1          1-к. квартира, 34,9 м², 4/6 эт.       1-к. квартира  34,9 м²
# 2            2-к. квартира, 36 м², 1/2 эт.       2-к. квартира    36 м²
# 3            2-к. квартира, 37 м², 3/5 эт.       2-к. квартира    37 м²
# 4          2-к. квартира, 44,8 м², 3/5 эт.       2-к. квартира  44,8 м²
# ...                                    ...                 ...      ...
# 200832    2-к. квартира, 64,2 м², 7/24 эт.       2-к. квартира  64,2 м²
# 200833    2-к. квартира, 64,2 м², 8/24 эт.       2-к. квартира  64,2 м²
# 200834    2-к. квартира, 64,2 м², 6/24 эт.       2-к. квартира  64,2 м²
# 200835    2-к. квартира, 64,2 м², 5/24 эт.       2-к. квартира  64,2 м²
# 200836    2-к. квартира, 64,2 м², 3/24 эт.       2-к. квартира  64,2 м²
#
#             Этаж        Цена Цена за м2            Название жк  \
# 0        5/5 эт.     1975000      68103                    NaN
# 1        4/6 эт.     3700000     106017                    NaN
# 2        1/2 эт.     2600000      72222                    NaN
# 3        3/5 эт.     3350000      90541                    NaN
# 4        3/5 эт.     5400000     120536                    NaN
# ...          ...         ...        ...                    ...
# 200832  7/24 эт.  11877000.0   185000.0  ЖК "Рекорд" 2 очередь
# 200833  8/24 эт.  11877000.0   185000.0  ЖК "Рекорд" 2 очередь
# 200834  6/24 эт.  11877000.0   185000.0  ЖК "Рекорд" 2 очередь
# 200835  5/24 эт.  11556000.0   180000.0  ЖК "Рекорд" 2 очередь
# 200836  3/24 эт.  11556000.0   180000.0  ЖК "Рекорд" 2 очередь
#
#                   Район                                      Улица  \
# 0         р-н Ленинский  микрорайон Черемошники, Кузнецкий пер., 5
# 1         р-н Кировский                           ул. Матросова, 6
# 2       р-н Октябрьский                        ул. Мичурина, 99Ас4
# 3         р-н Ленинский                           ул. Говорова, 18
# 4         р-н Кировский                             ул. Гоголя, 61
# ...                 ...                                        ...
# 200832  р-н Карасунский                 ул. Новороссийская, лит. 2
# 200833  р-н Карасунский                 ул. Новороссийская, лит. 2
# 200834  р-н Карасунский                 ул. Новороссийская, лит. 2
# 200835  р-н Карасунский                 ул. Новороссийская, лит. 2
# 200836  р-н Карасунский                 ул. Новороссийская, лит. 2
#
#        Дата публикации  Тип продавца                   Продавец  \
# 0       12 часов назад  Частное лицо                        NaN
# 1         6 дней назад  Частное лицо                        NaN
# 2        22 часа назад     Агентство  ОФИС ПРОДАЖ «ЗАСТРОЙЩИКА»
# 3         4 часа назад  Частное лицо                        NaN
# 4         2 часа назад  Частное лицо                        NaN
# ...                ...           ...                        ...
# 200832  3 недели назад    Застройщик      ЖК "Рекорд" 2 очередь
# 200833  3 недели назад    Застройщик      ЖК "Рекорд" 2 очередь
# 200834  3 недели назад    Застройщик      ЖК "Рекорд" 2 очередь
# 200835  3 недели назад    Застройщик      ЖК "Рекорд" 2 очередь
# 200836  3 недели назад    Застройщик      ЖК "Рекорд" 2 очередь
#
#                                        Ссылка на продавца  \
# 0                                                     NaN
# 1                                                     NaN
# 2       https://www.avito.ru/user/c245de34b6855769043d...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 200832  https://www.avito.ru/user/9baab164afea22c5cf7a...
# 200833  https://www.avito.ru/user/9baab164afea22c5cf7a...
# 200834  https://www.avito.ru/user/9baab164afea22c5cf7a...
# 200835  https://www.avito.ru/user/9baab164afea22c5cf7a...
# 200836  https://www.avito.ru/user/9baab164afea22c5cf7a...
#
#        Завершённых объявлений       ad_id
# 0                         NaN  3169985711
# 1                         NaN  2739762184
# 2                         388  2861453708
# 3                         NaN  2859068275
# 4                         NaN  2920724735
# ...                       ...         ...
# 200832                    NaN  2919396604
# 200833                    NaN  2918873627
# 200834                    NaN  2918970728
# 200835                    NaN  2919298481
# 200836                    NaN  2918860133
#
# [200837 rows x 16 columns]

# %%
files_avito = sorted(files_avito, key=lambda x: datetime.strptime(x[:8], '%d-%m-%y'))
files_cian = sorted(files_cian, key=lambda x: datetime.strptime(x[5:13], '%d-%m-%y'))

# %%
a = [1,2,3]
b = [4,5,3]

# %%
# avito
diff_list = []
for i in range(len(files_avito)):
    if i - 1 >=0:
        print('compare ' + files_avito[i], files_avito[i-1])
        test_avito_1 = pd.read_csv('saved_shit/' + files_avito[i], delimiter=';')
        test_avito_1['ad_id'] = test_avito_1['Ссылка'].apply(lambda x: x.split('_')[-1])
        test_avito_1['ad_id'] = test_avito_1['ad_id'].astype('int64')

        test_avito_pre = pd.read_csv('saved_shit/' + files_avito[i - 1], delimiter=';')
        test_avito_pre['ad_id'] = test_avito_pre['Ссылка'].apply(lambda x: x.split('_')[-1])
        test_avito_pre['ad_id'] = test_avito_pre['ad_id'].astype('int64')

        diff_ad_id = len(set(test_avito_1.ad_id.to_list()) - set(test_avito_pre.ad_id.to_list()))

        print(diff_ad_id, 'записей между 2 файлами; в рублях:                       ', diff_ad_id * 0.15)
        
        diff_all_ad_id = len(set(test_avito_1.ad_id.to_list()) - set(all_ad_id))
        print(diff_all_ad_id, 'записей между новым файлом и всеми остальными; в рублях: ', diff_all_ad_id * 0.15)
        all_ad_id.extend(test_avito_1.ad_id.to_list())
        print()
    else: # first file
        test_avito_new = pd.read_csv('saved_shit/' + files_avito[i], delimiter=';')
        test_avito_new['ad_id'] = test_avito_new['Ссылка'].apply(lambda x: x.split('_')[-1])
        test_avito_new['ad_id'] = test_avito_new['ad_id'].astype('int64')
        
        all_ad_id = test_avito_new.ad_id.to_list()
        
        print('первый файл - все новые: ', len(set(test_avito_new.ad_id.to_list())))
        print()
# Out:
# первый файл - все новые:  172756
#
# compare 26-04-23 (без дублей).csv 25-04-23 (без дублей).csv
# 18960 записей между 2 файлами; в рублях:                        2844.0
# 18960 записей между новым файлом и всеми остальными; в рублях:  2844.0
#
# compare 27-04-23 (без дублей).csv 26-04-23 (без дублей).csv
# 12043 записей между 2 файлами; в рублях:                        1806.45
# 6829 записей между новым файлом и всеми остальными; в рублях:  1024.35
#
# compare 28-04-23 (без дублей).csv 27-04-23 (без дублей).csv
# 25723 записей между 2 файлами; в рублях:                        3858.45
# 16228 записей между новым файлом и всеми остальными; в рублях:  2434.2
#
# compare 29-04-23 (без дублей).csv 28-04-23 (без дублей).csv
# 19246 записей между 2 файлами; в рублях:                        2886.9
# 6237 записей между новым файлом и всеми остальными; в рублях:  935.55
#
# compare 30-04-23 (без дублей).csv 29-04-23 (без дублей).csv
# 13862 записей между 2 файлами; в рублях:                        2079.2999999999997
# 2453 записей между новым файлом и всеми остальными; в рублях:  367.95
#
# compare 01-05-23 (без дублей).csv 30-04-23 (без дублей).csv
# 17128 записей между 2 файлами; в рублях:                        2569.2
# 2397 записей между новым файлом и всеми остальными; в рублях:  359.55
#
# compare 02-05-23 (без дублей).csv 01-05-23 (без дублей).csv
# 21430 записей между 2 файлами; в рублях:                        3214.5
# 3324 записей между новым файлом и всеми остальными; в рублях:  498.59999999999997
#
# compare 03-05-23 (без дублей).csv 02-05-23 (без дублей).csv
# 19807 записей между 2 файлами; в рублях:                        2971.0499999999997
# 3982 записей между новым файлом и всеми остальными; в рублях:  597.3
#
# compare 04-05-23 (без дублей).csv 03-05-23 (без дублей).csv
# 18613 записей между 2 файлами; в рублях:                        2791.95
# 3507 записей между новым файлом и всеми остальными; в рублях:  526.05
#
# compare 05-05-23 (без дублей).csv 04-05-23 (без дублей).csv
# 22163 записей между 2 файлами; в рублях:                        3324.45
# 5314 записей между новым файлом и всеми остальными; в рублях:  797.1
#
# compare 06-05-23 (без дублей).csv 05-05-23 (без дублей).csv
# 18727 записей между 2 файлами; в рублях:                        2809.0499999999997
# 2664 записей между новым файлом и всеми остальными; в рублях:  399.59999999999997
#
# compare 07-05-23 (без дублей).csv 06-05-23 (без дублей).csv
# 12720 записей между 2 файлами; в рублях:                        1908.0
# 1995 записей между новым файлом и всеми остальными; в рублях:  299.25
#
# compare 08-05-23 (без дублей).csv 07-05-23 (без дублей).csv
# 12548 записей между 2 файлами; в рублях:                        1882.1999999999998
# 1707 записей между новым файлом и всеми остальными; в рублях:  256.05

# %%
# cian
diff_list = []
for i in range(len(files_cian)):
    if i - 1 >=0:
        print('compare ' + files_cian[i], files_cian[i-1])
        test_cian_1 = pd.read_csv('saved_shit/' + files_cian[i], delimiter=',')
        test_cian_1['ad_id'] = test_cian_1['Ссылка'].apply(lambda x: x.split('/')[-2])
        test_cian_1['ad_id'] = test_cian_1['ad_id'].astype('int64')

        test_cian_pre = pd.read_csv('saved_shit/' + files_cian[i - 1], delimiter=',')
        test_cian_pre['ad_id'] = test_cian_pre['Ссылка'].apply(lambda x: x.split('/')[-2])
        test_cian_pre['ad_id'] = test_cian_pre['ad_id'].astype('int64')

        diff_ad_id = len(set(test_cian_1.ad_id.to_list()) - set(test_cian_pre.ad_id.to_list()))

        print(diff_ad_id, 'записей между 2 файлами; в рублях:                       ', diff_ad_id * 0.15)
        
        diff_all_ad_id = len(set(test_cian_1.ad_id.to_list()) - set(all_ad_id))
        print(diff_all_ad_id, 'записей между новым файлом и всеми остальными; в рублях: ', diff_all_ad_id * 0.15)
        all_ad_id.extend(test_cian_1.ad_id.to_list())
        print()
    else: # first file
        test_cian_new = pd.read_csv('saved_shit/' + files_cian[i], delimiter=',')
        test_cian_new['ad_id'] = test_cian_new['Ссылка'].apply(lambda x: x.split('/')[-2])
        test_cian_new['ad_id'] = test_cian_new['ad_id'].astype('int64')
        
        all_ad_id = test_cian_new.ad_id.to_list()
        
        print('первый файл - все новые: ', len(set(test_avito_new.ad_id.to_list())))
        print()
# Out:
# первый файл - все новые:  172756
#
# compare циан 26-04-23 (без дублей).csv циан 25-04-23 (без дублей).csv
# 5751 записей между 2 файлами; в рублях:                        862.65
# 5751 записей между новым файлом и всеми остальными; в рублях:  862.65
#
# compare циан 27-04-23 (без дублей).csv циан 26-04-23 (без дублей).csv
# 32326 записей между 2 файлами; в рублях:                        4848.9
# 9316 записей между новым файлом и всеми остальными; в рублях:  1397.3999999999999
#
# compare циан 28-04-23 (без дублей).csv циан 27-04-23 (без дублей).csv
# 9441 записей между 2 файлами; в рублях:                        1416.1499999999999
# 4697 записей между новым файлом и всеми остальными; в рублях:  704.55
#
# compare циан 29-04-23 (без дублей).csv циан 28-04-23 (без дублей).csv
# 10451 записей между 2 файлами; в рублях:                        1567.6499999999999
# 2538 записей между новым файлом и всеми остальными; в рублях:  380.7
#
# compare циан 30-04-23 (без дублей).csv циан 29-04-23 (без дублей).csv
# 8297 записей между 2 файлами; в рублях:                        1244.55
# 1672 записей между новым файлом и всеми остальными; в рублях:  250.79999999999998
#
# compare циан 01-05-23 (без дублей).csv циан 30-04-23 (без дублей).csv
# 8055 записей между 2 файлами; в рублях:                        1208.25
# 2592 записей между новым файлом и всеми остальными; в рублях:  388.8
#
# compare циан 02-05-23 (без дублей).csv циан 01-05-23 (без дублей).csv
# 14760 записей между 2 файлами; в рублях:                        2214.0
# 3854 записей между новым файлом и всеми остальными; в рублях:  578.1
#
# compare циан 03-05-23 (без дублей).csv циан 02-05-23 (без дублей).csv
# 14927 записей между 2 файлами; в рублях:                        2239.0499999999997
# 6076 записей между новым файлом и всеми остальными; в рублях:  911.4
#
# compare циан 04-05-23 (без дублей).csv циан 03-05-23 (без дублей).csv
# 11917 записей между 2 файлами; в рублях:                        1787.55
# 4198 записей между новым файлом и всеми остальными; в рублях:  629.6999999999999
#
# compare циан 05-05-23 (без дублей).csv циан 04-05-23 (без дублей).csv
# 14502 записей между 2 файлами; в рублях:                        2175.2999999999997
# 5107 записей между новым файлом и всеми остальными; в рублях:  766.05
#
# compare циан 06-05-23 (без дублей).csv циан 05-05-23 (без дублей).csv
# 9811 записей между 2 файлами; в рублях:                        1471.6499999999999
# 2257 записей между новым файлом и всеми остальными; в рублях:  338.55
#
# compare циан 07-05-23 (без дублей).csv циан 06-05-23 (без дублей).csv
# 5636 записей между 2 файлами; в рублях:                        845.4
# 1495 записей между новым файлом и всеми остальными; в рублях:  224.25

# %%
files_avito[0]
# Out:
# '25-04-23 (без дублей).csv'

# %%
files_avito[-1]
# Out:
# '08-05-23 (без дублей).csv'

# %%
test_avito_1 = pd.read_csv('saved_shit/' + files_avito[0], delimiter=';')
test_avito_1['ad_id'] = test_avito_1['Ссылка'].apply(lambda x: x.split('_')[-1])
test_avito_1['ad_id'] = test_avito_1['ad_id'].astype('int64')

test_avito_last = pd.read_csv('saved_shit/' + files_avito[-1], delimiter=';')
test_avito_last['ad_id'] = test_avito_last['Ссылка'].apply(lambda x: x.split('_')[-1])
test_avito_last['ad_id'] = test_avito_last['ad_id'].astype('int64')

# %%
set(test_avito_1.ad_id.to_list()) - set(test_avito_last.ad_id.to_list())
# Out:
# {2950299649,
#  2602303494,
#  2433613835,
#  2868903949,
#  2782265362,
#  2892759059,
#  2919104530,
#  2858549269,
#  2752774165,
#  2393899032,
#  2466775066,
#  2791440416,
