# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import sys
sys.path.insert(1, 'C:/Users/pnknv/Documents/GitHub/yadisk_loader')
from main_utils import *

# %% [markdown]
# # logging

# %%
import logging
import time
from test_logging import *
from pathlib import Path
import shutil

# %%
local_save_dir_data = create_load_save_dir('data')

# %%
for i in range(0,2):
    logging.basicConfig(filename=(Path.cwd()/'ya_loader.log').as_posix(), filemode='w', encoding='cp1251', 
                    level=logging.DEBUG, format='%(asctime)s [%(levelname)-8s] %(message)s')
    num = 0
    while num<4:
        time.sleep(2)
        logging.info('ok run log in oth')
        some_val_from_lto = log_test_other(num)
        logging.info(f'this is whacha get {some_val_from_lto}')
        if num == 2:
            odd_num = log_test_tqdm(7)
            logging.info(f'odd num list is: {odd_num}')
        else:
            logging.info(f'num is {num} so were not ready to tqdm')
            time.sleep(5)   
        num += 1
    src_file = Path.cwd()/'ya_loader.log'
    dst_file = Path(local_save_dir_data)/f'log_{get_today_date()}.log'
    shutil.copy(src_file, dst_file)

# %%
a = pd.read_csv(Path.cwd()/'saved_data_csv/cian_dadata_request_26_04_2023.csv', encoding='cp1251', index_col=0)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27694 entries, 0 to 27693
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   house_fias_id  23784 non-null  object
#  1   data           27694 non-null  object
#  2   geo_lat        27694 non-null  float64
#  3   geo_lon        27694 non-null  float64
#  4   street         27367 non-null  object
#  5   house          27569 non-null  object
#  6   qc             27694 non-null  int64
#  7   result         27694 non-null  object
#  8   qc_geo         27694 non-null  int64
#  9   ad_id          27694 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.3+ MB

# %%
a
# Out:
#                               house_fias_id  \
# 0      a3062811-f3ce-45e2-a05d-556d7f688b4d
# 1                                       NaN
# 2      9e8b0478-ceda-481e-ae0f-4dff24dbf2b0
# 3      4f388b64-35f9-430f-a2e9-8679a552c369
# 4      4f388b64-35f9-430f-a2e9-8679a552c369
# ...                                     ...
# 27689                                   NaN
# 27690  a3353f93-eba0-42d2-8875-8f921679d4c6
# 27691  68cc8e55-cded-44f0-855d-cb36cefa73c6
# 27692                                   NaN
# 27693                                   NaN
#
#                                                     data    geo_lat  \
# 0      {'source': 'Республика Татарстан; Набережные Ч...  55.709690
# 1      {'source': 'Республика Татарстан; Набережные Ч...  55.698329
# 2      {'source': 'Республика Татарстан; Набережные Ч...  55.743462
# 3      {'source': 'Республика Татарстан; Казань; р-н ...  55.738383
# 4      {'source': 'Республика Татарстан; Казань; р-н ...  55.738383
# ...                                                  ...        ...
# 27689  {'source': 'Новосибирская область; Новосибирск...  55.024230
# 27690  {'source': 'Новосибирская область; Новосибирск...  55.055793
# 27691  {'source': 'Новосибирская область; Новосибирск...  55.065257
# 27692  {'source': 'Новосибирская область; Новосибирск...  55.058940
# 27693  {'source': 'Новосибирская область; Новосибирск...  55.058940
#
#          geo_lon                  street  house  qc  \
# 0      52.373213        Николая Мальнева      3   0
# 1      52.327857                     NaN      3   1
# 2      52.395916        Вазила Мавликова      3   0
# 3      49.159615                     NaN      3   1
# 4      49.159615                     NaN      3   1
# ...          ...                     ...    ...  ..
# 27689  82.927921  Октябрьская магистраль     50   1
# 27690  82.914566                 Красный    104   1
# 27691  82.912848                 Красный  218/4   1
# 27692  82.916811                Овражная     2А   1
# 27693  82.916811                Овражная     2А   1
#
#                                                   result  qc_geo      ad_id
# 0      Респ Татарстан, г Набережные Челны, ул Николая...       0  277413781
# 1      Респ Татарстан, г Набережные Челны, п Красные ...       0  279271829
# 2      Респ Татарстан, г Набережные Челны, ул Вазила ...       4  285793261
# 3                  г Казань, тер Военный городок-33, д 3       0  286529782
# 4                  г Казань, тер Военный городок-33, д 3       0  286529795
# ...                                                  ...     ...        ...
# 27689     г Новосибирск, ул Октябрьская магистраль, д 50       2  286253139
# 27690                г Новосибирск, пр-кт Красный, д 104       0  284839197
# 27691              г Новосибирск, пр-кт Красный, д 218/4       1  282949106
# 27692                   г Новосибирск, ул Овражная, д 2А       2  286627092
# 27693                   г Новосибирск, ул Овражная, д 2А       2  286627386
#
# [27694 rows x 10 columns]

# %%
len(set([123123, 123, 277413781]) - set(a.ad_id.astype(int).to_list()))
# Out:
# 2

# %%
local_save_dir_data = create_load_save_dir('data')

# %%
Path.cwd()/'ya_loader.log'
# Out:
# WindowsPath('C:/Users/pnknv/Documents/GitHub/yadisk_loader/dev_check_jupyter/ya_loader.log')

# %%
local_save_dir_data
# Out:
# 'C:/Users/pnknv/Documents/GitHub/yadisk_loader/dev_check_jupyter/saved_data_csv'

# %%
Path(local_save_dir_data)/f'log_{get_today_date()[:10]}.log'
# Out:
# WindowsPath('C:/Users/pnknv/Documents/GitHub/yadisk_loader/dev_check_jupyter/saved_data_csv/log_27/04/2023.log')

# %%
Path.cwd()/local_save_dir_data/'ya_loader.log'
# Out:
# WindowsPath('C:/Users/pnknv/Documents/GitHub/yadisk_loader/dev_check_jupyter/saved_data_csv/ya_loader.log')

# %%
get_today_date()
# Out:
# '27/04/2023, 22:27:20'

# %%
get_today_date()[:10].replace(f'/', '_')
# Out:
# '27_04_2023'

# %%
src_file = Path.cwd()/'ya_loader.log'

dst_file = Path(local_save_dir_data)/f'log_{get_today_date()[:10].replace("/", "_")}.log'

src_file.rename(dst_file)
# Out:
# WindowsPath('C:/Users/pnknv/Documents/GitHub/yadisk_loader/dev_check_jupyter/saved_data_csv/log_27_04_2023.log')

# %%
Path.

# %%
### логи работают

# %%
### добавить

# %% [markdown]
# Необходимо создать алгоритм обновления существующих и добавления несуществующих файлов в realty </br>
# В prices необходимо добавлять все пришедшие цены

# %% [markdown]
# # вопросы
# ### 0. ЧТО НУЖНО ДОБАВИТЬ
#  <b>ad_id в realty и houses в bigint</b> </br>
#  <b>добавить колонку с названиями городов из авито из ссылки</b> </br>
#  <b>добавить индекс к ad_id realty</b> </br>
#  <b>добавлять темповую таблицу для обновления realty</b> </br>
#
# ### 1. Колонки
# Какие из колонок могут измениться? </br>
# Ключ: ад_айди + ссылка, все остальные на новые значения, STATUS = ? STATUS_NEW=? house_id=?
# ### 2. Обновление тест базы
# Как часто происходи?

# %%
st_time = datetime.now()
print('Скрипт запущен: ', get_today_date())
# Out:
# Скрипт запущен:  27/04/2023, 21:26:03

# %%
ssh_host, ssh_port, ssh_username, ssh_password, \
database_username, database_password, database_name, \
localhost, localhost_port, table_name, ya_token, ya_api, ya_link = get_config()

# %%
local_save_dir_avito = create_load_save_dir('avito')
local_save_dir_cian = create_load_save_dir('cian')

# %%
sql_server, sql_engine = get_sql_engine(ssh_host, ssh_port, ssh_username, ssh_password, localhost,
                                        localhost_port, database_username, database_password, database_name)

# %%
sql_engine
# Out:
# Engine(mariadb+pymysql://app_nedvizhk_usr:***@127.0.0.1:53755/app_nedvizhka_db)

# %%
sql_engine.connect()

# %%
handled_files_avito = get_saved_files_names('avito')
handled_files_cian = get_saved_files_names('cian')

# %%
files_to_process_avito = ['27-03-23 (без дублей).csv']
files_to_process_cian = ['циан 14-04-23 (без дублей) new.csv']

# %% [markdown]
# #### функции для новой таблицы

# %%
create_table_query = \
    """CREATE TABLE `temp_realty` (
      `id` int(11) NOT NULL AUTO_INCREMENT,
      `source_id` int(11) DEFAULT NULL,
      `ad_id` BIGINT DEFAULT NULL,
      `city_id` int(11) DEFAULT NULL,
      `district_id` int(11) DEFAULT NULL,
      `type_id` int(11) DEFAULT NULL,
      `addr` varchar(255) DEFAULT NULL,
      `square` float DEFAULT '0',
      `floor` int(11) DEFAULT NULL,
      `house_floors` int(11) DEFAULT NULL,
      `link` varchar(512) DEFAULT NULL,
      `date` timestamp NULL DEFAULT CURRENT_TIMESTAMP,
      `status` int(11) DEFAULT '0',
      `version` int(11) DEFAULT '0',
      `offer_from` varchar(255) DEFAULT NULL,
      `status_new` int(1) NOT NULL DEFAULT '0',
      `house_id` int(11) DEFAULT NULL,
      PRIMARY KEY (`id`)
    ) ENGINE=InnoDB DEFAULT CHARSET=utf8 AVG_ROW_LENGTH=2048 ROW_FORMAT=DYNAMIC;"""

index_show_query = \
f"""SHOW indexes FROM temp_realty"""

index_create_query = \
f"""CREATE INDEX index_ad_id_temp
    ON temp_realty (ad_id);"""

clear_temp_table_query = \
    """DELETE FROM temp_realty"""

# %%
def get_exist_ad_id(engine, source):
    source_id = 2 if source == 'cian' else 3
    ad_id_query = f'SELECT ad_id FROM realty where source_id = {source_id}'
    try:
        con_obj = engine.connect()
        ad_id_db = pd.read_sql(text(ad_id_query), con=con_obj)
        con_obj.close()
        exc_code = None
    except Exception as exc:
        print(traceback.format_exc())
        ad_id_db = None
        exc_code = exc.code
    return ad_id_db, exc_code

# %%
exist_ad_id, exc_code = get_exist_ad_id(sql_engine, 'cian')

# %%
try:
    con_obj = engine.connect()
    con_obj.close()
except:
    server, engine = get_sql_engine(ssh_host, ssh_port, ssh_username, ssh_password, localhost,
                                        localhost_port, database_username, database_password, database_name)
    print('подключение к базе восстановлено')

# %%
try:
    1/0
except Exception as exc:
    print(exc)
# Out:
# division by zero

# %%
exist_ad_id
# Out:
#             ad_id
# 0       272391397
# 1       272330693
# 2       272390645
# 3       272382949
# 4       272328204
# ...           ...
# 742514  285376232
# 742515  285766622
# 742516  285765451
# 742517  273587329
# 742518  284808119
#
# [742519 rows x 1 columns]
# 2023-04-27 21:51:00,023| ERROR   | Socket exception: Удаленный хост принудительно разорвал существующее подключение (10054)

# %%
def get_date_from_name(fname):
    try:
        return datetime.strptime(fname.replace("(без дублей)", "").replace("циан", "").replace(" ", "")[:8], "%d-%m-%y")
    except:
        return datetime.strptime(Path(fname).stem.replace("(без дублей)", "").replace("циан", "").replace(" ", "")[:8],
                                 "%d-%m-%y")

# %%
def get_index_temp(engine):
    index_show_query = \
        f"""SHOW indexes FROM temp_realty"""
    try:
        con_obj = engine.connect()
        index_db = pd.read_sql(text(index_show_query), con=con_obj)
        con_obj.close()
        exc_code = None
    except Exception as exc:
        print(traceback.format_exc())
        index_db = None
        exc_code = exc.code
    return index_db, exc_code

# %%
con_obj = sql_engine.connect()
try:
    con_obj.execute(text(create_table_query))
    if 'index_ad_id_temp' in get_index_temp(sql_engine)[0].Key_name.to_list():
        pass
    else:
        con_obj.execute(text(index_create_query))
    con_obj.commit()
    print('Временная таблица создана')
except:
    con_obj.execute(text(clear_temp_table_query))
    con_obj.commit()
    print('Временная таблица очищена')
con_obj.close()
# Out:
# Временная таблица очищена

# %%
ilya_c[ilya_c['Адрес'].apply(lambda x: 'кварталы 38' in x)]
# Out:
#                                            Ссылка  \
# 2      https://kazan.cian.ru/sale/flat/285520808/
# 3      https://kazan.cian.ru/sale/flat/285520807/
# 38     https://kazan.cian.ru/sale/flat/286089243/
# 49     https://kazan.cian.ru/sale/flat/285991792/
# 60     https://kazan.cian.ru/sale/flat/284292121/
# ...                                           ...
# 82039  https://kazan.cian.ru/sale/flat/284071519/
# 82042  https://kazan.cian.ru/sale/flat/284049781/
# 82047  https://kazan.cian.ru/sale/flat/284012160/
# 82073  https://kazan.cian.ru/sale/flat/280572686/
# 82112  https://kazan.cian.ru/sale/flat/254605850/
#
#                               Заголовок       Комнат  Площадь        Этаж  \
# 2        3-комн. кв., 64,9 м², 4/9 этаж  3-комн. кв.  64,9 м²    4/9 этаж
# 3        3-комн. кв., 65,8 м², 6/9 этаж  3-комн. кв.  65,8 м²    6/9 этаж
# 38       2-комн. кв., 50,5 м², 2/9 этаж  2-комн. кв.  50,5 м²    2/9 этаж
# 49     1-комн. кв., 43,2 м², 14/16 этаж  1-комн. кв.  43,2 м²  14/16 этаж
# 60       3-комн. кв., 64,5 м², 2/9 этаж  3-комн. кв.  64,5 м²    2/9 этаж
# ...                                 ...          ...      ...         ...
# 82039    2-комн. кв., 50,7 м², 6/9 этаж  2-комн. кв.  50,7 м²    6/9 этаж
# 82042    3-комн. кв., 65,9 м², 1/9 этаж  3-комн. кв.  65,9 м²    1/9 этаж
# 82047    3-комн. кв., 68,5 м², 1/9 этаж  3-комн. кв.  68,5 м²    1/9 этаж
# 82073    3-комн. кв., 65,9 м², 1/9 этаж  3-комн. кв.  65,9 м²    1/9 этаж
# 82112     2-комн. кв., 57 м², 1/15 этаж  2-комн. кв.    57 м²   1/15 этаж
#
#           Цена  Цена за м2                         Название жк  \
# 2      7700000      118644                                 NaN
# 3      7600000      115502                                 NaN
# 38     7700000      152475                                 NaN
# 49     7649000      177060  ЖК «ул. Академика Лаврентьева, 11»
# 60     7500000      116279                                 NaN
# ...        ...         ...                                 ...
# 82039  6850000      135108                                 NaN
# 82042  6700000      101669                                 NaN
# 82047  6500000       94891                                 NaN
# 82073  6700000      101669                                 NaN
# 82112  6350000      111404                                 NaN
#
#                                                    Адрес  \
# 2      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 3      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 38     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 49     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 60     Республика Татарстан;Казань;р-н Ново-Савиновск...
# ...                                                  ...
# 82039  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82042  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82047  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82073  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82112  Республика Татарстан;Казань;р-н Ново-Савиновск...
#
#                        Дата публикации            Тип продавца  \
# 2          неделю назад (5 апр, 00:17)  Агентство недвижимости
# 3       9 часов назад (сегодня, 00:41)  Агентство недвижимости
# 38               вчера (12 апр, 22:52)             Собственник
# 49       три дня назад (10 апр, 11:05)  Агентство недвижимости
# 60       два дня назад (11 апр, 12:30)  Агентство недвижимости
# ...                                ...                     ...
# 82039  17 часов назад (сегодня, 00:41)  Агентство недвижимости
# 82042      неделю назад (7 апр, 09:38)  Агентство недвижимости
# 82047   2 недели назад (30 мар, 17:27)  Агентство недвижимости
# 82073   2 месяца назад (21 янв, 20:31)             Собственник
# 82112     полгода назад (5 сен, 09:29)                 Риелтор
#
#                                  Продавец
# 2                            ЭТАЖИ КАЗАНЬ
# 3                            ЭТАЖИ КАЗАНЬ
# 38                           ID 101964921
# 49                Лас Вегас - Офис продаж
# 60                        Макромир Казань
# ...                                   ...
# 82039                        ЭТАЖИ КАЗАНЬ
# 82042  Центральное агентство недвижимости
# 82047                            Домотека
# 82073                         ID 16737042
# 82112                         ID 48339885
#
# [127 rows x 12 columns]

# %%
def get_districts_1(engine):
    districts_query = f"SELECT DISTINCT id, city_id, name FROM districts"
    try:
        con_obj = engine.connect()
        districts_query_db = pd.read_sql(text(districts_query), con=con_obj)
        con_obj.close()
    except Exception as exc:
        try:
            con_obj.close()
            print(exc)
            districts_query_db = None
        except:
            print(exc)
            districts_query_db = None
    return districts_query_db

# %%
def district_from_rn_mkrn_1(realty_row, all_districts, sql_engine):
    # для записи новых районов создадим датафрейм и получим последний id района
    add_districts_df = pd.DataFrame(columns=['city_id', 'name'])
    current_max_id = all_districts.id.max()
    # для работы функции создадим объекты текущего р-н и мкр
    current_rn = None
    current_mkrn = None
    if not np.isnan(realty_row['city_id']):
        for addr_part in realty_row.addr.split(';')[:4]:
            if 'мкр.' in addr_part:
                current_mkrn = addr_part.replace(' мкр. ', '').replace('мкр. ', '')
                continue
            elif 'р-н' in addr_part:
                current_rn = addr_part.replace(' р-н ', '').replace('р-н ', '')
                continue
            else:
                continue
        if current_rn == None and current_mkrn == None:
            return None
        else:
            district_name = current_mkrn if current_mkrn != None else current_rn
            district_intersection = all_districts[(all_districts.city_id == realty_row.city_id) & (all_districts.name == district_name)]
            if len(district_intersection) == 0:
                # обновление данных из districts на случай если дистрикт добавлялся во время исполнения скрипта
                all_districts_upd = get_districts_1(sql_engine)
                district_intersection_upd = all_districts_upd[
                    (all_districts_upd.city_id == realty_row.city_id) & (all_districts_upd.name == district_name)]
                current_max_id = int(all_districts_upd.id.max())
                # если в обновленном districts нет данных о районе - добавляем
                if len(district_intersection_upd) == 0:
                    add_districts_df.loc[len(add_districts_df)] = [realty_row.city_id, district_name]
#                     add_districts_df.to_sql(name='districts', con=sql_engine, if_exists='append', method='multi', index=False)
                    print('добавлен новый район {} "{}" в districts функцией district_from_rn_mkrn'.format(current_max_id + 1, district_name))
                    return current_max_id + 1
                # если данные о районе есть, возвращаем id
                else:
                    return district_intersection_upd.iloc[0, 0]
            else:
                return district_intersection.iloc[0, 0]
    else:
        return None

# %%
def create_realty_1(df, fname, sql_engine, source, dict_realty_type=dict_realty_cian_avito):
    try:
        # new table
        cian_realty = pd.DataFrame()

        # сбор данных из таблиц в бд
        city_df, source_df, exc_code = get_tables_info(sql_engine)

        # удаление дубликатов
        df.drop_duplicates(subset=['Ссылка'], keep='last', inplace=True)
        df.reset_index(drop=True, inplace=True)
        
        # add source
        df['source'] = df['Ссылка'].apply(lambda x: x.split('.')[1])

        # source_id
        source_df_dict = source_df.set_index('id').to_dict()['name']
        cian_realty['source_id'] = df['source'].apply(lambda x: source_id_from_link(x, source_df_dict, 'cian'))

        # ad_id
        cian_realty['ad_id'] = df['Ссылка'].apply(lambda x: x.split('/')[-2])
        
        # city
        df['city'] = df['Адрес'].apply(lambda x: x.split(';')[1])

        # city_id
        city_df_dict = city_df.set_index('id').to_dict()['name']
        cian_realty['city_id'] = df['city'].apply(lambda x: city_id_from_link(x, city_df_dict))

        # удалить записи где city_id пустой (записи городов, которые не присутствуют в списке городов для парсинга)
        # ind_to_drop = cian_realty[(cian_realty['city_id'].isna())].index.tolist()
        # cian_realty.drop(ind_to_drop, inplace=True)
        # df.drop(ind_to_drop, inplace=True)
        # cian_realty.city_id = cian_realty.city_id.astype(int)

        # type_id

        cian_realty['type_id'] = df['Комнат'].apply(lambda x: type_id_from_room(x, dict_realty_type))
        # удалить записи аукционов и других объяв где не опредлен type_id
        ind_to_drop = cian_realty[(cian_realty['type_id'].isna())].index.tolist()
        cian_realty.drop(ind_to_drop, inplace=True)
        df.drop(ind_to_drop, inplace=True)
        cian_realty.type_id = cian_realty.type_id.astype(int)
        
        print('check')
        print(len(df[df['Адрес'].apply(lambda x: ',' in x)]))
        
        # addr
#         cian_realty['addr'] = df['Адрес'].apply(lambda x: x.replace(',',';'))
        cian_realty['addr'] = df['Адрес']
    
        print('check')
        print(len(cian_realty[cian_realty.addr.apply(lambda x: ',' in x)]))
    
        # district_id после addr потому что в нем используется адрес
        all_districts = get_districts_1(sql_engine)
        cian_realty['district_id'] = cian_realty.apply(
            lambda row: district_from_rn_mkrn_1(row, all_districts, sql_engine), axis=1)

        # square
        cian_realty['square'] = df['Площадь'].apply(lambda x: square_from_ploshad(x))

        # floor
        cian_realty['floor'], cian_realty['house_floors'] = zip(*df['Этаж'].apply(floor_floors_from_etazh))

        # link
        cian_realty['link'] = df['Ссылка']

        # date
        file_date = get_date_from_name(fname)
        cian_realty['date'] = file_date

        # status
        cian_realty['status'] = 0

        # version
        current_source = cian_realty.source_id.unique()[0]
        current_date = datetime.now().date()
        last_version = get_version_db(sql_engine, current_date, current_source)[0].iloc[0, 0]
        if last_version == None:
            current_version = 1
        else:
            current_version = last_version + 1

        cian_realty['version'] = current_version

        # offer_from
        cian_realty['offer_from'] = df['Тип продавца']

        # status_new
        cian_realty['status_new'] = 1

        # add fields of price and price_sqrm
        cian_realty['price'], cian_realty['price_sqrm'] = df['Цена'], df['Цена за м2']

        # delete rows where one of important values isna
        cian_realty_check = cian_realty[['source_id', 'ad_id', 'type_id', 'addr', 'link', 'date', 'version']]
        values_na_ind = cian_realty_check[cian_realty_check.isna().any(axis=1)].index
        if len(values_na_ind) > 0:
            cian_realty = cian_realty.drop(values_na_ind)

        cian_realty_to_return = cian_realty[['source_id', 'ad_id', 'city_id', 'district_id', 'type_id',
                                             'addr', 'square', 'floor','house_floors', 'link', 'date',
                                             'status', 'version', 'offer_from', 'status_new', 'price', 'price_sqrm']]
    except Exception as ex:
        print(traceback.format_exc())
        cian_realty_to_return = pd.DataFrame()
        file_date = None
    return cian_realty_to_return, file_date

# %%
def process_realty_1(local_dir, file_to_process, sql_engine, source):
    saved_files = get_local_files(local_dir)
    realty_df = pd.DataFrame()
    file_date = None
    for f_ind in range(len(saved_files)):
        if Path(saved_files[f_ind]).name == file_to_process:
            try:
                if source == 'avito':
                    saved_file = pd.read_csv(saved_files[f_ind], delimiter=';', encoding='utf8')
                    realty_df, file_date = create_realty_1(saved_file, Path(saved_files[f_ind]).stem,
                                                         sql_engine, 'avito')
                elif source == 'cian':
                    saved_file = pd.read_csv(saved_files[f_ind], delimiter=',', encoding='utf8')
                    realty_df, file_date = create_realty_1(saved_file, Path(saved_files[f_ind]).stem,
                                                         sql_engine, 'cian')
            except Exception as ex:
                print(traceback.format_exc())
                print('Не удалось прочитать файл из {}: '.format(source), Path(saved_files[f_ind]))
        else:
            pass
    if len(realty_df) != 0:
        print('Успешно обработан файл {} для realty'.format(file_to_process))
        error_status = False
        return realty_df, file_date, error_status
    else:
        error_status = True
        print('Файл {} не удалось обнаружить для realty'.format(file_to_process))
        return realty_df, file_date, error_status

# %%
new_c = pd.read_csv('циан 14-04-23 (без дублей) new.csv', delimiter=',', encoding='utf8')

# %%
new_c['addr'] = new_c['Адрес']

# %%
new_c[new_c.addr.apply(lambda x: 'кварталы' in x)]
# Out:
#                                            Ссылка  \
# 2      https://kazan.cian.ru/sale/flat/285520808/
# 3      https://kazan.cian.ru/sale/flat/285520807/
# 10     https://kazan.cian.ru/sale/flat/285472812/
# 16     https://kazan.cian.ru/sale/flat/285465376/
# 19     https://kazan.cian.ru/sale/flat/285439290/
# ...                                           ...
# 82079  https://kazan.cian.ru/sale/flat/280460331/
# 82080  https://kazan.cian.ru/sale/flat/280446216/
# 82081  https://kazan.cian.ru/sale/flat/280434852/
# 82089  https://kazan.cian.ru/sale/flat/280318936/
# 82112  https://kazan.cian.ru/sale/flat/254605850/
#
#                               Заголовок       Комнат  Площадь        Этаж  \
# 2        3-комн. кв., 64,9 м², 4/9 этаж  3-комн. кв.  64,9 м²    4/9 этаж
# 3        3-комн. кв., 65,8 м², 6/9 этаж  3-комн. кв.  65,8 м²    6/9 этаж
# 10       3-комн. кв., 65,6 м², 7/9 этаж  3-комн. кв.  65,6 м²    7/9 этаж
# 16      1-комн. кв., 46,2 м², 9/15 этаж  1-комн. кв.  46,2 м²   9/15 этаж
# 19         1-комн. кв., 65 м², 7/9 этаж  1-комн. кв.    65 м²    7/9 этаж
# ...                                 ...          ...      ...         ...
# 82079    2-комн. кв., 50,7 м², 9/9 этаж  2-комн. кв.  50,7 м²    9/9 этаж
# 82080  1-комн. кв., 50,9 м², 14/18 этаж  1-комн. кв.  50,9 м²  14/18 этаж
# 82081      2-комн. кв., 52 м², 2/9 этаж  2-комн. кв.    52 м²    2/9 этаж
# 82089   1-комн. кв., 44,6 м², 2/19 этаж  1-комн. кв.  44,6 м²   2/19 этаж
# 82112     2-комн. кв., 57 м², 1/15 этаж  2-комн. кв.    57 м²   1/15 этаж
#
#           Цена  Цена за м2            Название жк  \
# 2      7700000      118644                    NaN
# 3      7600000      115502                    NaN
# 10     7300000      111280                    NaN
# 16     7600000      164502                    NaN
# 19     7230000      111231                    NaN
# ...        ...         ...                    ...
# 82079  6500000      128205                    NaN
# 82080  6871500      135000          ЖК «Акварель»
# 82081  6500000      125000                    NaN
# 82089  6700000      150224  ЖК «Золотая середина»
# 82112  6350000      111404                    NaN
#
#                                                    Адрес  \
# 2      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 3      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 10     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 16     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 19     Республика Татарстан;Казань;р-н Ново-Савиновск...
# ...                                                  ...
# 82079  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82080  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82081  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82089  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82112  Республика Татарстан;Казань;р-н Ново-Савиновск...
#
#                       Дата публикации            Тип продавца      Продавец  \
# 2         неделю назад (5 апр, 00:17)  Агентство недвижимости  ЭТАЖИ КАЗАНЬ
# 3      9 часов назад (сегодня, 00:41)  Агентство недвижимости  ЭТАЖИ КАЗАНЬ
# 10     7 часов назад (сегодня, 03:22)  Агентство недвижимости  ЭТАЖИ КАЗАНЬ
# 16        неделю назад (2 апр, 20:46)             Собственник  ID 101337528
# 19               вчера (вчера, 10:42)  Агентство недвижимости          КАИР
# ...                               ...                     ...           ...
# 82079  6 часов назад (сегодня, 10:57)  Агентство недвижимости       Альтера
# 82080     неделю назад (6 апр, 10:15)  Агентство недвижимости   ID 78901442
# 82081            вчера (вчера, 17:50)  Агентство недвижимости          ФЛЭТ
# 82089            вчера (вчера, 17:50)  Агентство недвижимости          ФЛЭТ
# 82112    полгода назад (5 сен, 09:29)                 Риелтор   ID 48339885
#
#                                                     addr
# 2      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 3      Республика Татарстан;Казань;р-н Ново-Савиновск...
# 10     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 16     Республика Татарстан;Казань;р-н Ново-Савиновск...
# 19     Республика Татарстан;Казань;р-н Ново-Савиновск...
# ...                                                  ...
# 82079  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82080  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82081  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82089  Республика Татарстан;Казань;р-н Ново-Савиновск...
# 82112  Республика Татарстан;Казань;р-н Ново-Савиновск...
#
# [798 rows x 13 columns]

# %%
new_c[new_c.addr.apply(lambda x: 'кварталы 38' in x)].iloc[1,8]
# Out:
# 'Республика Татарстан;Казань;р-н Ново-Савиновский;мкр. кварталы 38;27;улица Академика Лаврентьева;4'

# %%
new_c[new_c.addr.apply(lambda x: 'кварталы 38' in x)].iloc[1,0]
# Out:
# 'https://kazan.cian.ru/sale/flat/285520807/'

# %%
test_c = new_c[new_c.addr.apply(lambda x: ',' in x)]

# %%
def tryx(x):
    try:
        return x.split(';')[3]
    except:
        return None

# %%
test_c['test_distr'] = test_c.addr.apply(lambda x: tryx(x))

# %%
test_c.test_distr.unique()
# Out:
# array(['мкр. 7,8', 'мкр. 9,10,11', 'мкр. кварталы 29,30'], dtype=object)

# %%
all_districts = get_districts_1(sql_engine)
cian_realty['district_id'] = cian_realty.apply(lambda row: district_from_rn_mkrn_1(row, all_districts, sql_engine), axis=1)

# %%
# check cian from ilya
for filename in files_to_process_cian:
    # обработка realty циан
    print('обработка файла {} для cian'.format(filename))
    df_cian_realty, file_date, error_file_processing = process_realty_1(local_save_dir_cian, filename,
                                                                      sql_engine, 'cian')

    # проверка состояния
    if error_file_processing:
        print('Ошибка при обработке файлов из CIAN {}. Перезапуск скрипта...'.format(filename))
        error_processing_files = True
        break
    else:
        error_processing_files = False
        print('Выгрузка в таблицу realty обработанного файла из cian:', filename)
# Out:
# обработка файла циан 14-04-23 (без дублей) new.csv для cian
# check
# 278
# check
# 278
# добавлен новый район 506 "кварталы 38" в districts функцией district_from_rn_mkrn
# добавлен новый район 506 "кварталы 38" в districts функцией district_from_rn_mkrn
# добавлен новый район 506 "кварталы 25" в districts функцией district_from_rn_mkrn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [84], line 5
#       2 for filename in files_to_process_cian:
#       3     # обработка realty циан
#       4     print('обработка файла {} для cian'.format(filename))
# ----> 5     df_cian_realty, file_date, error_file_processing = process_realty_1(local_save_dir_cian, filename,
#       6                                                                       sql_engine, 'cian')
#       8     # проверка состояния
#       9     if error_file_processing:
#
# Cell In [83], line 14, in process_realty_1(local_dir, file_to_process, sql_engine, source)
#      12     elif source == 'cian':
#      13         saved_file = pd.read_csv(saved_files[f_ind], delimiter=',', encoding='utf8')
# ---> 14         realty_df, file_date = create_realty_1(saved_file, Path(saved_files[f_ind]).stem,
#      15                                              sql_engine, 'cian')
#      16 except Exception as ex:
#      17     print(traceback.format_exc())
#
# Cell In [82], line 57, in create_realty_1(df, fname, sql_engine, source, dict_realty_type)
#      55 # district_id после addr потому что в нем используется адрес
#      56 all_districts = get_districts_1(sql_engine)
# ---> 57 cian_realty['district_id'] = cian_realty.apply(
#      58     lambda row: district_from_rn_mkrn_1(row, all_districts, sql_engine), axis=1)
#      60 # square
#      61 cian_realty['square'] = df['Площадь'].apply(lambda x: square_from_ploshad(x))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:8848, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8837 from pandas.core.apply import frame_apply
#    8839 op = frame_apply(
#    8840     self,
#    8841     func=func,
#    (...)
#    8846     kwargs=kwargs,
#    8847 )
# -> 8848 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# Cell In [82], line 58, in create_realty_1.<locals>.<lambda>(row)
#      55 # district_id после addr потому что в нем используется адрес
#      56 all_districts = get_districts_1(sql_engine)
#      57 cian_realty['district_id'] = cian_realty.apply(
# ---> 58     lambda row: district_from_rn_mkrn_1(row, all_districts, sql_engine), axis=1)
#      60 # square
#      61 cian_realty['square'] = df['Площадь'].apply(lambda x: square_from_ploshad(x))
#
# Cell In [67], line 25, in district_from_rn_mkrn_1(realty_row, all_districts, sql_engine)
#      22 district_intersection = all_districts[(all_districts.city_id == realty_row.city_id) & (all_districts.name == district_name)]
#      23 if len(district_intersection) == 0:
#      24     # обновление данных из districts на случай если дистрикт добавлялся во время исполнения скрипта
# ---> 25     all_districts_upd = get_districts_1(sql_engine)
#      26     district_intersection_upd = all_districts_upd[
#      27         (all_districts_upd.city_id == realty_row.city_id) & (all_districts_upd.name == district_name)]
#      28     current_max_id = int(all_districts_upd.id.max())
#
# Cell In [66], line 6, in get_districts_1(engine)
#       4     con_obj = engine.connect()
#       5     districts_query_db = pd.read_sql(text(districts_query), con=con_obj)
# ----> 6     con_obj.close()
#       7 except Exception as exc:
#       8     try:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:1232, in Connection.close(self)
#    1209 """Close this :class:`_engine.Connection`.
#    1210
#    1211 This results in a release of the underlying database
#    (...)
#    1228
#    1229 """
#    1231 if self._transaction:
# -> 1232     self._transaction.close()
#    1233     skip_reset = True
#    1234 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:2553, in Transaction.close(self)
#    2542 """Close this :class:`.Transaction`.
#    2543
#    2544 If this transaction is the base transaction in a begin/commit
#    (...)
#    2550
#    2551 """
#    2552 try:
# -> 2553     self._do_close()
#    2554 finally:
#    2555     assert not self.is_active
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:2691, in RootTransaction._do_close(self)
#    2690 def _do_close(self) -> None:
# -> 2691     self._close_impl()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:2677, in RootTransaction._close_impl(self, try_deactivate)
#    2675 try:
#    2676     if self.is_active:
# -> 2677         self._connection_rollback_impl()
#    2679     if self.connection._nested_transaction:
#    2680         self.connection._nested_transaction._cancel()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:2669, in RootTransaction._connection_rollback_impl(self)
#    2668 def _connection_rollback_impl(self) -> None:
# -> 2669     self.connection._rollback_impl()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:1118, in Connection._rollback_impl(self)
#    1116     self.engine.dialect.do_rollback(self.connection)
#    1117 except BaseException as e:
# -> 1118     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:2328, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2326     else:
#    2327         assert exc_info[1] is not None
# -> 2328         raise exc_info[1].with_traceback(exc_info[2])
#    2329 finally:
#    2330     del self._reentrant_error
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:1116, in Connection._rollback_impl(self)
#    1114         self._log_info("ROLLBACK")
#    1115 try:
# -> 1116     self.engine.dialect.do_rollback(self.connection)
#    1117 except BaseException as e:
#    1118     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\default.py:657, in DefaultDialect.do_rollback(self, dbapi_connection)
#     656 def do_rollback(self, dbapi_connection):
# --> 657     dbapi_connection.rollback()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymysql\connections.py:480, in Connection.rollback(self)
#     473 """
#     474 Roll back the current transaction.
#     475
#     476 See `Connection.rollback() <https://www.python.org/dev/peps/pep-0249/#rollback>`_
#     477 in the specification.
#     478 """
#     479 self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
# --> 480 self._read_ok_packet()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymysql\connections.py:443, in Connection._read_ok_packet(self)
#     442 def _read_ok_packet(self):
# --> 443     pkt = self._read_packet()
#     444     if not pkt.is_ok_packet():
#     445         raise err.OperationalError(2014, "Command Out of Sync")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymysql\connections.py:692, in Connection._read_packet(self, packet_type)
#     690 buff = bytearray()
#     691 while True:
# --> 692     packet_header = self._read_bytes(4)
#     693     # if DEBUG: dump_packet(packet_header)
#     695     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pymysql\connections.py:732, in Connection._read_bytes(self, num_bytes)
#     730 while True:
#     731     try:
# --> 732         data = self._rfile.read(num_bytes)
#     733         break
#     734     except (IOError, OSError) as e:
#
# File C:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df_cian_realty
# Out:
#        source_id      ad_id  city_id  district_id  type_id  \
# 0              2  279841013     12.0        362.0        3
# 1              2  279841011     12.0        176.0        3
# 2              2  279830163     12.0        506.0        4
# 3              2  279806940     12.0        362.0        3
# 4              2  279798485     12.0        147.0        4
# ...          ...        ...      ...          ...      ...
# 67854          2  284260313     12.0        143.0        4
# 67855          2  284252006     12.0        155.0        5
# 67856          2  284241806     12.0        362.0        4
# 67857          2  284240049     12.0        507.0        4
# 67858          2  284236587     12.0        143.0        5
#
#                                                     addr  square floor  \
# 0      Республика Татарстан; Казань; р-н Советский; м...    41.0     1
# 1      Республика Татарстан; Казань; р-н Советский; м...    40.0    10
# 2      Республика Татарстан; Казань; р-н Приволжский;...    53.5     9
# 3      Республика Татарстан; Казань; р-н Советский; у...    35.9     6
# 4      Республика Татарстан; Казань; р-н Вахитовский;...    53.0     6
# ...                                                  ...     ...   ...
# 67854  Республика Татарстан; Казань; р-н Советский; м...    55.5     3
# 67855  Республика Татарстан; Казань; р-н Советский; м...    71.0     1
# 67856  Республика Татарстан; Казань; р-н Советский; у...    48.5     3
# 67857  Республика Татарстан; Казань; р-н Ново-Савинов...    49.8     2
# 67858  Республика Татарстан; Казань; р-н Советский; м...    68.0     4
#
#       house_floors                                        link       date  \
# 0               20  https://kazan.cian.ru/sale/flat/279841013/ 2023-04-10
# 1               16  https://kazan.cian.ru/sale/flat/279841011/ 2023-04-10
# 2                9  https://kazan.cian.ru/sale/flat/279830163/ 2023-04-10
# 3               17  https://kazan.cian.ru/sale/flat/279806940/ 2023-04-10
# 4                9  https://kazan.cian.ru/sale/flat/279798485/ 2023-04-10
# ...            ...                                         ...        ...
# 67854           10  https://kazan.cian.ru/sale/flat/284260313/ 2023-04-10
# 67855           10  https://kazan.cian.ru/sale/flat/284252006/ 2023-04-10
# 67856           19  https://kazan.cian.ru/sale/flat/284241806/ 2023-04-10
# 67857            9  https://kazan.cian.ru/sale/flat/284240049/ 2023-04-10
# 67858            7  https://kazan.cian.ru/sale/flat/284236587/ 2023-04-10
#
#        status  version              offer_from  status_new    price  \
# 0           0      287  Агентство недвижимости           1  6790000
# 1           0      287  Агентство недвижимости           1  6800000
# 2           0      287  Агентство недвижимости           1  6700000
# 3           0      287  Агентство недвижимости           1  6980000
# 4           0      287                     NaN           1  6500000
# ...       ...      ...                     ...         ...      ...
# 67854       0      287  Агентство недвижимости           1  6990000
# 67855       0      287                     NaN           1  6800000
# 67856       0      287  Агентство недвижимости           1  6700000
# 67857       0      287  Агентство недвижимости           1  6900000
# 67858       0      287  Агентство недвижимости           1  6600000
#
#        price_sqrm
# 0          165610
# 1          170000
# 2          125234
# 3          194429
# 4          122642
# ...           ...
# 67854      125946
# 67855       95775
# 67856      138144
# 67857      138554
# 67858       97059
#
# [67750 rows x 17 columns]

# %%
df_cian_realty.city_id.value_counts().sort_index()
# Out:
# 2.0     33323
# 4.0      5425
# 5.0      7858
# 6.0       163
# 7.0      5019
# 12.0    11257
# 13.0        4
# 15.0        1
# 17.0     4693
# Name: city_id, dtype: int64

# %%
# check avito from ilya
for filename in files_to_process_cian:
    # обработка realty циан
    print('обработка файла {} для cian'.format(filename))
    df_cian_realty, file_date, error_file_processing = process_realty_1(local_save_dir_cian, filename,
                                                                      sql_engine, 'cian')

    # проверка состояния
    if error_file_processing:
        print('Ошибка при обработке файлов из CIAN {}. Перезапуск скрипта...'.format(filename))
        error_processing_files = True
        break
    else:
        error_processing_files = False
        print('Выгрузка в таблицу realty обработанного файла из cian:', filename)

# %%
for filename in files_to_process_cian:
    # обработка realty циан
    print('обработка файла {} для cian'.format(filename))
    df_cian_realty, file_date, error_file_processing = process_realty(local_save_dir_cian, '27-03-23.csv',
                                                                      sql_engine, 'cian')

    # проверка состояния
    if error_file_processing:
        print('Ошибка при обработке файлов из CIAN {}. Перезапуск скрипта...'.format(filename))
        error_processing_files = True
        break
    else:
        error_processing_files = False
        print('Выгрузка в таблицу realty обработанного файла из cian:', filename)

    # выгрузка и обновление данных в таблице realty
#     error_create_temp_realty, error_getting_ad_id, error_loading_into_realty, error_updating_realty = \
#         load_and_update_realty_db(sql_engine, df_cian_realty, 'cian')

#     if any([error_create_temp_realty, error_getting_ad_id,
#             error_loading_into_realty,error_updating_realty]):
#         close_sql_connection(sql_server, sql_engine)
#         print('Ошибка:', show_error([error_create_temp_realty, error_getting_ad_id,
#                                      error_loading_into_realty, error_updating_realty]))
#         print('Не удалось добавить данные в таблицу {}. Перезапуск скрипта...'.format('realty'))
#         time.sleep(10)
#         break

# %%
df_cian_realty.head(5)
# Out:
#    source_id      ad_id  city_id  district_id  type_id  \
# 0          2  210197059      5.0          NaN        5
# 1          2  213575526      5.0          NaN        5
# 2          2  232012292      5.0          NaN        2
# 3          2  233965925      5.0          NaN        3
# 4          2  239179225      5.0          NaN        7
#
#                                                 addr  square  floor  \
# 0      Краснодарский край; Анапа; улица Горького; 2А   107.0      7
# 1  Краснодарский край; Анапа; улица Краснозеленых...   106.0      6
# 2       Краснодарский край; Анапа; улица Ленина; 194    20.0      1
# 3      Краснодарский край; Анапа; улица Толстого; 81    29.0      1
# 4  Краснодарский край; Анапа; Владимирская улица;...   140.0     13
#
#    house_floors                                        link       date  \
# 0            12  https://anapa.cian.ru/sale/flat/210197059/ 2023-03-27
# 1             7  https://anapa.cian.ru/sale/flat/213575526/ 2023-03-27
# 2             9  https://anapa.cian.ru/sale/flat/232012292/ 2023-03-27
# 3             3  https://anapa.cian.ru/sale/flat/233965925/ 2023-03-27
# 4            13  https://anapa.cian.ru/sale/flat/239179225/ 2023-03-27
#
#    status  version              offer_from  status_new     price  price_sqrm
# 0       0      287             Собственник           1  24000000      224299
# 1       0      287                 Риелтор           1  10100000       95283
# 2       0      287                 Риелтор           1   2100000      105000
# 3       0      287  Агентство недвижимости           1   4500000      155172
# 4       0      287             Собственник           1  15300000      109286

# %%
df_cian_realty.head(5)

# %%
ilya_c = pd.read_csv('циан 01-04-23 (без дублей).csv', delimiter=';', encoding='utf8')

# %%
ilya_c
# Out:
#                                            Ссылка  \
# 0      https://kazan.cian.ru/sale/flat/278951388/
# 1      https://kazan.cian.ru/sale/flat/278945093/
# 2      https://kazan.cian.ru/sale/flat/278939145/
# 3      https://kazan.cian.ru/sale/flat/278871110/
# 4      https://kazan.cian.ru/sale/flat/278838651/
# ...                                           ...
# 67593  https://anapa.cian.ru/sale/flat/285539567/
# 67594  https://anapa.cian.ru/sale/flat/285533182/
# 67595  https://anapa.cian.ru/sale/flat/285531619/
# 67596  https://anapa.cian.ru/sale/flat/285526541/
# 67597  https://anapa.cian.ru/sale/flat/285523095/
#
#                               Заголовок       Комнат  Площадь        Этаж  \
# 0         1-комн. кв., 40 м², 5/18 этаж  1-комн. кв.    40 м²   5/18 этаж
# 1          3-комн. кв., 71 м², 2/9 этаж  3-комн. кв.    71 м²    2/9 этаж
# 2        1-комн. кв., 39,1 м², 7/7 этаж  1-комн. кв.  39,1 м²    7/7 этаж
# 3        1-комн. кв., 32,7 м², 5/9 этаж  1-комн. кв.  32,7 м²    5/9 этаж
# 4       1-комн. кв., 42,8 м², 8/14 этаж  1-комн. кв.  42,8 м²   8/14 этаж
# ...                                 ...          ...      ...         ...
# 67593    1-комн. кв., 37,3 м², 5/8 этаж  1-комн. кв.  37,3 м²    5/8 этаж
# 67594  1-комн. кв., 34,7 м², 13/13 этаж  1-комн. кв.  34,7 м²  13/13 этаж
# 67595   1-комн. кв., 41,1 м², 3/14 этаж  1-комн. кв.  41,1 м²   3/14 этаж
# 67596     1-комн. кв., 33 м², 1/16 этаж  1-комн. кв.    33 м²   1/16 этаж
# 67597      1-комн. кв., 36 м², 5/8 этаж  1-комн. кв.    36 м²    5/8 этаж
#
#           Цена  Цена за м2        Название жк  \
# 0      6500000      162500    ЖК «Молодежный»
# 1      6700000       94366                NaN
# 2      6600000      168798                NaN
# 3      6500000      198777                NaN
# 4      6590000      153972                NaN
# ...        ...         ...                ...
# 67593  5500000      147453  ЖК «Времена года»
# 67594  5350000      154179      ЖК «Лазурный»
# 67595  5700000      138686      ЖК «Лазурный»
# 67596  5300000      160606  ЖК «Два Адмирала»
# 67597  5300000      147222                NaN
#
#                                                    Адрес  \
# 0      Республика Татарстан, Казань, р-н Советский, м...
# 1      Республика Татарстан, Казань, р-н Приволжский,...
# 2      Республика Татарстан, Казань, р-н Советский, м...
# 3      Республика Татарстан, Казань, р-н Вахитовский,...
# 4      Республика Татарстан, Казань, р-н Ново-Савинов...
# ...                                                  ...
# 67593            Краснодарский край, Анапа, улица Мирная
# 67594      Краснодарский край, Анапа, Крестьянская улица
# 67595  Краснодарский край, Анапа, Крестьянская улица,...
# 67596            Краснодарский край, Анапа, улица Ленина
# 67597     Краснодарский край, Анапа, улица Омелькова, 28
#
#                        Дата публикации            Тип продавца  \
# 0         неделю назад (23 мар, 17:34)  Агентство недвижимости
# 1        3 недели назад (6 мар, 17:51)                 Риелтор
# 2                 вчера (вчера, 18:35)  Агентство недвижимости
# 3                 вчера (вчера, 17:52)  Агентство недвижимости
# 4                 вчера (вчера, 18:34)  Агентство недвижимости
# ...                                ...                     ...
# 67593             вчера (вчера, 14:33)  Агентство недвижимости
# 67594    два дня назад (30 мар, 11:24)  Агентство недвижимости
# 67595             вчера (вчера, 11:58)  Агентство недвижимости
# 67596  10 часов назад (сегодня, 12:26)                     NaN
# 67597    два дня назад (30 мар, 02:20)  Агентство недвижимости
#
#                   Продавец
# 0                  Премьер
# 1      Руслан Гаптелбариев
# 2             ЭТАЖИ КАЗАНЬ
# 3             ЭТАЖИ КАЗАНЬ
# 4             ЭТАЖИ КАЗАНЬ
# ...                    ...
# 67593             Академия
# 67594        Анапа-Партнер
# 67595             ПрайдPRO
# 67596          ID 44315944
# 67597         Альтернатива
#
# [67598 rows x 12 columns]

# %%
ilya_c[ilya_c['Адрес'].apply(lambda x: 'армавир' in x)]
# Out:
# Empty DataFrame
# Columns: [Ссылка, Заголовок, Комнат, Площадь, Этаж, Цена, Цена за м2, Название жк, Адрес, Дата публикации, Тип продавца, Продавец]
# Index: []

# %%
ilya_c['city'] = ilya_c['Ссылка'].apply(lambda x: x.split('//')[1].split('.')[0])

# %%
ilya_c['city'].value_counts()
# Out:
# krasnodar       33402
# kazan           11033
# anapa            8208
# novorossiysk     5536
# chelyabinsk      5055
# tomsk            4364
# Name: city, dtype: int64

# %%
ilya_a = pd.read_csv("13-04-23 (без дублей).csv", delimiter=';', encoding='utf8')

# %%
ilya_a['city'] = ilya_a['Ссылка'].apply(lambda x: x.split('/')[3])

# %%
ilya_a['city'].value_counts()
# Out:
# krasnodar       82135
# kazan           19440
# chelyabinsk      7375
# novorossiysk     4659
# anapa            2688
# tomsk            2145
# armavir           734
# Name: city, dtype: int64

# %%
def create_realty_1(df, fname, sql_engine, source, dict_realty_type=dict_realty_cian_avito):
    try:
        # new table
        cian_realty = pd.DataFrame()

        # сбор данных из таблиц в бд
        city_df, source_df, exc_code = get_tables_info(sql_engine)

        # удаление дубликатов
        df.drop_duplicates(subset=['Ссылка'], keep='last', inplace=True)
        df.reset_index(drop=True, inplace=True)
        
        # add source
        df['source'] = df['Ссылка'].apply(lambda x: x.split('.')[1])

        # source_id
        source_df_dict = source_df.set_index('id').to_dict()['name']
        cian_realty['source_id'] = df['source'].apply(lambda x: source_id_from_link(x, source_df_dict, 'cian'))

        # ad_id
        cian_realty['ad_id'] = df['Ссылка'].apply(lambda x: x.split('/')[-2])
        
        # city
        df['city'] = df['Адрес'].apply(lambda x: x.split(', ')[1])

        # city_id
        city_df_dict = city_df.set_index('id').to_dict()['name']
        cian_realty['city_id'] = df['city'].apply(lambda x: city_id_from_link(x, city_df_dict))

        # удалить записи где city_id пустой (записи городов, которые не присутствуют в списке городов для парсинга)
        # ind_to_drop = cian_realty[(cian_realty['city_id'].isna())].index.tolist()
        # cian_realty.drop(ind_to_drop, inplace=True)
        # df.drop(ind_to_drop, inplace=True)
        # cian_realty.city_id = cian_realty.city_id.astype(int)

        # type_id

        cian_realty['type_id'] = df['Комнат'].apply(lambda x: type_id_from_room(x, dict_realty_type))
        # удалить записи аукционов и других объяв где не опредлен type_id
        ind_to_drop = cian_realty[(cian_realty['type_id'].isna())].index.tolist()
        cian_realty.drop(ind_to_drop, inplace=True)
        df.drop(ind_to_drop, inplace=True)
        cian_realty.type_id = cian_realty.type_id.astype(int)

        # addr
        cian_realty['addr'] = df['Адрес'].apply(lambda x: x.replace(',',';'))

        # district_id после addr потому что в нем используется адрес
        all_districts = get_districts_1(sql_engine)
        cian_realty['district_id'] = cian_realty.apply(
            lambda row: district_from_rn_mkrn(row, all_districts, sql_engine), axis=1)

        # square
        cian_realty['square'] = df['Площадь']

        # floor
        cian_realty['floor'], cian_realty['house_floors'] = df['floor'], df['house_floors']

        # link
        cian_realty['link'] = df['link']

        # date
        file_date = get_date_from_name(fname)
        cian_realty['date'] = file_date

        # status
        cian_realty['status'] = 0

        # version
        current_source = cian_realty.source_id.unique()[0]
        current_date = datetime.now().date()
        last_version = get_version_db(sql_engine, current_date, current_source)[0].iloc[0, 0]
        if last_version == None:
            current_version = 1
        else:
            current_version = last_version + 1

        cian_realty['version'] = current_version

        # offer_from
        cian_realty['offer_from'] = df['offer_from']

        # status_new
        cian_realty['status_new'] = 1

        # add fields of price and price_sqrm
        cian_realty['price'], cian_realty['price_sqrm'] = df['price'], df['price_sqrm']

        # delete rows where one of important values isna
        cian_realty_check = cian_realty[['source_id', 'ad_id', 'type_id', 'addr', 'link', 'date', 'version']]
        values_na_ind = cian_realty_check[cian_realty_check.isna().any(axis=1)].index
        if len(values_na_ind) > 0:
            cian_realty = cian_realty.drop(values_na_ind)

        cian_realty_to_return = cian_realty[['source_id', 'ad_id', 'city_id', 'district_id', 'type_id',
                                             'addr', 'square', 'floor','house_floors', 'link', 'date',
                                             'status', 'version', 'offer_from', 'status_new', 'price', 'price_sqrm']]
    except Exception as ex:
        print(traceback.format_exc())
        cian_realty_to_return = pd.DataFrame()
        file_date = None
    return cian_realty_to_return, file_date

# %%
def process_realty_1(local_dir, file_to_process, sql_engine, source):
    saved_files = get_local_files(local_dir)
    realty_df = pd.DataFrame()
    file_date = None
    for f_ind in range(len(saved_files)):
        if Path(saved_files[f_ind]).name == file_to_process:
            try:
                if source == 'avito':
                    saved_file = pd.read_csv(saved_files[f_ind], delimiter=';', encoding='utf8')
                    realty_df, file_date = create_realty_1(saved_file, Path(saved_files[f_ind]).stem,
                                                         sql_engine, 'avito')
                elif source == 'cian':
                    saved_file = pd.read_csv(saved_files[f_ind], delimiter=',', encoding='cp1251')
                    realty_df, file_date = create_realty_1(saved_file, Path(saved_files[f_ind]).stem,
                                                         sql_engine, 'cian')
            except Exception as ex:
                print(traceback.format_exc())
                print('Не удалось прочитать файл из {}: '.format(source), Path(saved_files[f_ind]))
        else:
            pass
    if len(realty_df) != 0:
        print('Успешно обработан файл {} для realty'.format(file_to_process))
        error_status = False
        return realty_df, file_date, error_status
    else:
        error_status = True
        print('Файл {} не удалось обнаружить для realty'.format(file_to_process))
        return realty_df, file_date, error_status

# %%
for filename in files_to_process_cian:
    # обработка realty циан
    print('обработка файла {} для cian'.format(filename))
    df_cian_realty, file_date, error_file_processing = process_realty(local_save_dir_cian, '27-03-23.csv',
                                                                      sql_engine, 'cian')

    # проверка состояния
    if error_file_processing:
        print('Ошибка при обработке файлов из CIAN {}. Перезапуск скрипта...'.format(filename))
        error_processing_files = True
        break
    else:
        error_processing_files = False
        print('Выгрузка в таблицу realty обработанного файла из cian:', filename)

    # выгрузка и обновление данных в таблице realty
#     error_create_temp_realty, error_getting_ad_id, error_loading_into_realty, error_updating_realty = \
#         load_and_update_realty_db(sql_engine, df_cian_realty, 'cian')

#     if any([error_create_temp_realty, error_getting_ad_id,
#             error_loading_into_realty,error_updating_realty]):
#         close_sql_connection(sql_server, sql_engine)
#         print('Ошибка:', show_error([error_create_temp_realty, error_getting_ad_id,
#                                      error_loading_into_realty, error_updating_realty]))
#         print('Не удалось добавить данные в таблицу {}. Перезапуск скрипта...'.format('realty'))
#         time.sleep(10)
#         break
# Out:
# обработка файла циан 10-04-23 (без дублей).csv для cian

# %%
error_create_temp_realty, error_getting_ad_id, error_loading_into_realty, error_updating_realty = \
        load_and_update_realty_db(sql_engine, df_cian_realty, 'cian')
# Out:
# Временная таблица очищена
# Загрузка новых объявлений в таблицу
# новые объявления добавлены, переход к обновлению существующих
# new_algo2
# Обновление данных завершено

# %%
error_create_temp_realty, error_getting_ad_id, error_loading_into_realty, error_updating_realty
# Out:
# (False, False, False, False)

# %%
for filename in files_to_process_cian:
    # обработка realty циан
    print('обработка файла {} для cian'.format(filename))
    df_cian_realty, file_date, error_file_processing = process_realty(local_save_dir_cian, filename,
                                                                      sql_engine, 'cian')

    # проверка состояния
    if error_file_processing:
        print('Ошибка при обработке файлов из CIAN {}. Перезапуск скрипта...'.format(filename))
        error_processing_files = True
        break
    else:
        error_processing_files = False
        print('Выгрузка в таблицу realty обработанного файла из cian:', filename)

    # загрузка realty в таблицу
    try:
#         df_cian_realty[list_realty_cols].to_sql(name='realty', con=sql_engine, if_exists='append',
#                                chunksize=7000, method='multi', index=False)
        # df_cian_realty.to_csv(f'{filename}_test_cian_realty.csv')
        error_writing_files = False
    except Exception as exc:
        print(exc)
        print('Не удалось добавить данные в таблицу {}. Перезапуск скрипта...'.format('realty'))
        error_writing_files = True
        break
# Out:
# обработка файла 27-03-23.csv для cian
# Успешно обработан файл 27-03-23.csv для realty
# Выгрузка в таблицу realty обработанного файла из cian: 27-03-23.csv

# %% [markdown]
# # апдейт

# %%
exist_ad_id = get_exist_ad_id(sql_engine, 'cian')[0].ad_id.to_list()

# %%
df_cian_realty_exist___ = df_cian_realty[df_cian_realty.ad_id.isin([])][list_realty_cols]

# %%
len(df_cian_realty_exist___)
# Out:
# 0

# %%
df_cian_realty_new
# Out:
#         source_id      ad_id  city_id  district_id  type_id  \
# 1189            2  270328443      5.0          NaN        6
# 3306            2  278996199      5.0          NaN        3
# 3433            2  279241124      5.0          NaN        2
# 3622            2  279601823      5.0          NaN        3
# 4159            2  280802412      5.0          NaN        3
# ...           ...        ...      ...          ...      ...
# 103599          2  285370017     17.0        387.0        4
# 103600          2  285370096     17.0        405.0        4
# 103601          2  285370463     17.0        417.0        4
# 103602          2  285373005     17.0        394.0        3
# 103603          2  285373491     17.0        391.0        5
#
#                                                      addr  square  floor  \
# 1189    Краснодарский край; Анапа; Владимирская улица;...    95.0     20
# 3306    Краснодарский край; Анапа; Алексеевка мкр; ули...    35.0      6
# 3433    Краснодарский край; Анапа; Таманская улица; 12...    26.0      5
# 3622        Краснодарский край; Анапа; улица Толстого; 26    35.5      2
# 4159                   Краснодарский край; Анапа; 18/3 ЖК    44.7      7
# ...                                                   ...     ...    ...
# 103599  Томская область; Томск; р-н Кировский; д. Лоск...    57.1      2
# 103600  Томская область; Томск; р-н Октябрьский; мкр. ...    53.0      8
# 103601  Томская область; Томск; р-н Ленинский; мкр. Ра...    53.0      6
# 103602  Томская область; Томск; р-н Ленинский; Черемош...    31.5      7
# 103603  Томская область; Томск; р-н Октябрьский; улица...    56.0      2
#
#         house_floors                                        link       date  \
# 1189              20  https://anapa.cian.ru/sale/flat/270328443/ 2023-03-27
# 3306               7  https://anapa.cian.ru/sale/flat/278996199/ 2023-03-27
# 3433               6  https://anapa.cian.ru/sale/flat/279241124/ 2023-03-27
# 3622               7  https://anapa.cian.ru/sale/flat/279601823/ 2023-03-27
# 4159              15  https://anapa.cian.ru/sale/flat/280802412/ 2023-03-27
# ...              ...                                         ...        ...
# 103599             4  https://tomsk.cian.ru/sale/flat/285370017/ 2023-03-27
# 103600            10  https://tomsk.cian.ru/sale/flat/285370096/ 2023-03-27
# 103601            10  https://tomsk.cian.ru/sale/flat/285370463/ 2023-03-27
# 103602            10  https://tomsk.cian.ru/sale/flat/285373005/ 2023-03-27
# 103603             5  https://tomsk.cian.ru/sale/flat/285373491/ 2023-03-27
#
#        status  version                 offer_from  status_new
# 1189     None      274                        NaN           1
# 3306     None      274                Собственник           1
# 3433     None      274     Агентство недвижимости           1
# 3622     None      274  Представитель застройщика           1
# 4159     None      274                 Застройщик           1
# ...       ...      ...                        ...         ...
# 103599   None      274                        NaN           1
# 103600   None      274     Агентство недвижимости           1
# 103601   None      274     Агентство недвижимости           1
# 103602   None      274     Агентство недвижимости           1
# 103603   None      274                    Риелтор           1
#
# [4188 rows x 15 columns]

# %%
df_cian_realty_exist = df_cian_realty[df_cian_realty.ad_id.isin(exist_ad_id)][list_realty_cols]
df_cian_realty_new = df_cian_realty[~df_cian_realty.ad_id.isin(exist_ad_id)][list_realty_cols]

# %%
df_cian_realty_exist.head(3)
# Out:
#    source_id      ad_id  city_id  district_id  type_id  \
# 0          2  210197059      5.0          NaN        5
# 1          2  213575526      5.0          NaN        5
# 2          2  232012292      5.0          NaN        2
#
#                                                 addr  square  floor  \
# 0      Краснодарский край; Анапа; улица Горького; 2А   107.0      7
# 1  Краснодарский край; Анапа; улица Краснозеленых...   106.0      6
# 2       Краснодарский край; Анапа; улица Ленина; 194    20.0      1
#
#    house_floors                                        link       date status  \
# 0            12  https://anapa.cian.ru/sale/flat/210197059/ 2023-03-27   None
# 1             7  https://anapa.cian.ru/sale/flat/213575526/ 2023-03-27   None
# 2             9  https://anapa.cian.ru/sale/flat/232012292/ 2023-03-27   None
#
#    version   offer_from  status_new
# 0      274  Собственник           1
# 1      274      Риелтор           1
# 2      274      Риелтор           1

# %%
# обновление данных
df_cian_realty_exist.to_sql(name='temp_realty', con=sql_engine, if_exists='append', chunksize=7000, method='multi', index=False)

con_obj = sql_engine.connect()
common_ids = tuple(df_cian_realty_exist.ad_id)
update_table_query = f"""update realty join temp_realty on realty.ad_id=temp_realty.ad_id
                        set realty.source_id = temp_realty.source_id,
                            realty.city_id = temp_realty.city_id,
                            realty.district_id = temp_realty.district_id,
                            realty.type_id = temp_realty.type_id,
                            realty.addr = temp_realty.addr,
                            realty.square = temp_realty.square,
                            realty.floor = temp_realty.floor,
                            realty.house_floors = temp_realty.house_floors,
                            realty.link = temp_realty.link,
                            realty.date = temp_realty.date,
                            realty.status = temp_realty.status,
                            realty.version = temp_realty.version,
                            realty.offer_from = temp_realty.offer_from,
                            realty.status_new = temp_realty.status_new,
                            realty.house_id = temp_realty.house_id
                         WHERE realty.ad_id in {common_ids}"""
con_obj.execute(text(update_table_query))
con_obj.commit()
con_obj.close()

# %%
# очистка данных из temp_realty
con_obj = sql_engine.connect()
con_obj.execute(text(clear_temp_table_query))
con_obj.commit()
con_obj.close()

# %%
# добавление данных 
df_cian_realty_new.to_sql(name='realty', con=sql_engine, if_exists='append', chunksize=7000, method='multi', index=False)
